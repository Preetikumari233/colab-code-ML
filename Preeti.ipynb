# %%
def remove_duplicates_without_set(input_list):
    unique_list = []
    for item in input_list:
        if item not in unique_list:
            unique_list.append(item)
    return unique_list


my_list = [1, 2, 2, 3, 4, 4, 5, 1]
cleaned_list = remove_duplicates_without_set(my_list)
print(f"Original list: {my_list}")
print(f"List with duplicates removed: {cleaned_list}")

# %%
my_second_list = ['apple', 'banana', 'orange', 'apple', 'grape', 'banana']
cleaned_second_list = remove_duplicates_without_set(my_second_list)
print(f"Original list: {my_second_list}")
print(f"List with duplicates removed: {cleaned_second_list}")

# %%
import math

print(f"e to the power of 1: {math.exp(1)}")
print(f"e to the power of 2: {math.exp(2)}")
# Out:
# e to the power of 1: 2.718281828459045
# e to the power of 2: 7.38905609893065

# %%
from collections import Counter

def count_char_frequency(input_string):
    """Counts the frequency of each character in a string if its length is > 50."""
    if len(input_string) <= 50:
        print(f"String length ({len(input_string)}) is not more than 50. Skipping character frequency count.")
        return {}

    return Counter(input_string)

# %% [markdown]
# ### Example Usage

# %%
long_string = "This is a very long string that definitely has more than fifty characters in it, so it should be processed." # Length is 108

print(f"\nString: '{long_string}'")
long_string_frequency = count_char_frequency(long_string)
if long_string_frequency:
    print("Character frequency (long string):")
    for char, count in long_string_frequency.items():
        print(f"'{char}': {count}")


short_string = "This is a short string."

print(f"\nString: '{short_string}'")
short_string_frequency = count_char_frequency(short_string)
if short_string_frequency:
    print("Character frequency (short string):")
    for char, count in short_string_frequency.items():
        print(f"'{char}': {count}")
# Out:
# String: 'This is a very long string that definitely has more than fifty characters in it, so it should be processed.'
# Character frequency (long string):
# 'T': 1
# 'h': 6
# 'i': 9
# 's': 9
# ' ': 19
# 'a': 6
# 'v': 1
# 'e': 8
# 'r': 6
# 'y': 3
# 'l': 3
# 'o': 5
# 'n': 5
# 'g': 2
# 't': 9
# 'd': 3
# 'f': 3
# 'm': 1
# 'c': 3
# ',': 1
# 'u': 1
# 'b': 1
# 'p': 1
# '.': 1
#
# String: 'This is a short string.'
# String length (23) is not more than 50. Skipping character frequency count.
